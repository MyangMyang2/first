# %%
import random
lotto=[]

while True:
  a=random.randint(1,45)
  lotto.append(a)
  lotto=set(lotto)
  lotto=list(lotto)
  if len(lotto)==6:
    break
print(lotto)
# Out:
# [32, 3, 4, 14, 20, 27]

# %%
print(random.sample(range(1,46),6))
# Out:
# [15, 10, 7, 2, 26, 30]
